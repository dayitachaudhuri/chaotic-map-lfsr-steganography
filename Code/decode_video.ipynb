# %% [markdown]
# Imports

# %%
from PIL import Image
import numpy as np
import cv2
from pylfsr import LFSR

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# - Any type to Binary Converter

# %%
def convertToBinary(data):
    if isinstance(data, str):
        return ''.join([ format(ord(i), "08b") for i in data ])
    elif isinstance(data, bytes) or isinstance(data, np.ndarray):
        return [ format(i, "08b") for i in data ]
    elif isinstance(data, int) or isinstance(data, np.uint8):
        return format(data, "08b")
    else:
        raise TypeError("Type not supported.")

# %%
print(list(convertToBinary(256)))
# Out:
# ['1', '0', '0', '0', '0', '0', '0', '0', '0']

# %% [markdown]
# - Binary to Decimal Converter

# %%
def binaryToDecimal(binary):
    decimal = 0
    for bit in binary:
        decimal = decimal*2 + int(bit)
    return decimal

# %% [markdown]
# - Convert image to matrix

# %%
def getImageMatrix(imageName):

    imageHandler = Image.open(imageName)
    pixels = imageHandler.load()
    color = 1
    if type(pixels[0,0]) == int:
        color = 0
    image_size = imageHandler.size
    
    rows = int(image_size[0])
    cols = int(image_size[1])
    image_matrix = []
    for row in range(rows):
        current_row = []
        for col in range(cols):
            current_row.append(pixels[row,col])
        image_matrix.append(current_row)
    
    return image_matrix, image_size, color

# %% [markdown]
# - Extract Frames From Video

# %%
def FrameCapture(path): 
  
    vidObj = cv2.VideoCapture(path) 
    count = 0
  
    success = 1
  
    while count < 100: 
        success, image = vidObj.read()
        if not success:
            print("Video End")
            return  
        count += 1
    
    cv2.imwrite("images/frame1.jpg", image) 

    while count < 200: 
        success, image = vidObj.read() 
        if not success:
            print("Video End")
            return 
        count += 1

    cv2.imwrite("images/frame2.jpg", image) 

    while count < 300: 
        success, image = vidObj.read() 
        if not success:
            print("Video End")
            return 
        count += 1

    cv2.imwrite("images/frame3.jpg", image) 

    while count < 400: 
        success, image = vidObj.read() 
        if not success:
            print("Video End")
            return 
        count += 1

    cv2.imwrite("images/frame4.jpg", image)

# %%
FrameCapture("images/original_video.mp4")
# Out:
# Video End

# %% [markdown]
# ## 2D Chaotic Map

# %% [markdown]
# - Hennon Map (Binary)

# %%
def HennonMapBinary(dimension, key):

    rows = dimension[0]
    cols = dimension[1]
    x = key[0]
    y = key[1]
    a = 1.4
    b = 0.3

    # Total Number of bitSequence produced
    sequenceSize = rows * cols
    bitSequenceSize = cols
    # Each bitSequence contains k bits
    bitSequence = []       
    # Each matrix contains m*n byteArray
    matrix = []

    for i in range(sequenceSize):
        x_next = y + 1 - (a * (x**2)) 
        y_next = b * x
        x = x_next
        y = y_next
        if x <= 0.4:
            bit = 0
        else:
            bit = 1

        bitSequence.append(bit) 

        # If Bit Sequence has k bits, convert it to decimal and add it to Byte Sequence.
        if i % bitSequenceSize == bitSequenceSize - 1:
            matrix.append(bitSequence)
            bitSequence = []

    return matrix

# %% [markdown]
# ## Encoding

# %%
def decode(videoname, hennonKey, poly):

    # Divide Encoded video into frames
    vidObj = cv2.VideoCapture("outputs/video_steg/encoded_video.avi") 
    success = True
    frames = []
    while success: 
        success, image = vidObj.read()
        frames.append(image)

    frame_usage = [0 for i in range(len(frames))]

    # Divide Original video into frames
    vidObj_or = cv2.VideoCapture(videoname) 
    success = True
    frames_or = []
    while success: 
        success, image_or = vidObj_or.read()
        frames_or.append(image_or)

    # print(frames, frames_or)
    print(frames)
    
    # Set Limit
    frame_size = (len(frames[0]), len(frames[0][0]))
    print(frame_size)
    frame_usage_limit = (frame_size[0] * frame_size[1] * 3) * 0.3

    # Find Delimiter
    delimiter1 = convertToBinary("!")
    delimiter2 = convertToBinary("=")

    data_index = 0
    data = []
    current = ""

    # Build LFSR to be used to choose frame
    frame_lfsr = LFSR(initstate = [1, 1, 1, 1, 1, 1, 1, 1], fpoly=poly, counter_start_zero=True)
    frame_index = 0

    flag = True

    while flag:

        # Choose Frame using LFSR
        frame_index = (frame_index + binaryToDecimal(frame_lfsr.state)) % len(frames)
        frame_lfsr.next()

        # If frame is already used, keep choosing next frame until unused frame is found.
        count = 0
        while frame_usage[frame_index] != 0:
            frame_index = (frame_index + binaryToDecimal(frame_lfsr.state)) % len(frames)
            frame_lfsr.next()
            count += 1
            if count > 100:
                print("frames exceeded")
                return
            
        print("frame selected", frame_index)

        # Build chaotic map and derive some available pixels for the frame
        map = HennonMapBinary(frame_size, hennonKey)

        availablePixels = []

        for i in range(frame_size[0]):
            for j in range(0,frame_size[1]):
                if map[i][j] == 1:
                    availablePixels.append([i,j,0])
        
        # Build LFSR for pixel choice
        pixel_lfsr = LFSR(initstate = [1, 1, 1, 1, 1, 1, 1, 1], fpoly=poly, counter_start_zero=True)
        pixel_index = 0

        while flag:

            # Choose pixel using LFSR from Available pixels
            pixel_index = (pixel_index + binaryToDecimal(pixel_lfsr.state)) % len(availablePixels)
            pixel_lfsr.next()

            # If pixel is already used 3 times, keep choosing next pixel until unused pixel is found.
            count = 0
            while availablePixels[pixel_index][2] > 2:
                pixel_index = (pixel_index + binaryToDecimal(pixel_lfsr.state)) % len(availablePixels)
                pixel_lfsr.next()
                count += 1
                if count > 100:
                    print("pixels exceeded")
                    return
            
            print("pixel selected", pixel_index)

            '''
            EACH PIXEL CAN BE USED AT MAX 3 TIMES. WE KEEP COUNT OF NUMBER OF USES AS USAGESTATE.

            IF USAGESTATE IS 0: XOR 2 DATA BITS WITH 2 LSB OF RED VALUE
            IF USAGESTATE IS 1: XOR 2 DATA BITS WITH 2 LSB OF BLUE VALUE
            IF USAGESTATE IS 2: XOR 2 DATA BITS WITH 2 LSB OF GREEN VALUE
            '''

            # Extract row, column and usagestate values.
            row = availablePixels[pixel_index][0]
            col = availablePixels[pixel_index][1]
            usageState = availablePixels[pixel_index][2]

            # Update with Red Value
            if usageState == 0:
                value = list(convertToBinary(frames[frame_index][row,col][0]))
                value_or = list(convertToBinary(frames_or[frame_index][row,col][0]))
                
                temp1 = str(int(value[-2]) ^ int(value_or[-2]))
                temp2 = str(int(value[-1]) ^ int(value_or[-1]))

            # Extract from Blue Value
            elif usageState == 1:
                value = list(convertToBinary(frames[frame_index][row,col][1]))
                value_or = list(convertToBinary(frames_or[frame_index][row,col][1]))
                
                temp1 = str(int(value[-2]) ^ int(value_or[-2]))
                temp2 = str(int(value[-1]) ^ int(value_or[-1]))
            
            # Extract from Green Value
            else:
                value = list(convertToBinary(frames[frame_index][row,col][2]))
                value_or = list(convertToBinary(frames_or[frame_index][row,col][2]))

                temp1 = str(int(value[-2]) ^ int(value_or[-2]))
                temp2 = str(int(value[-1]) ^ int(value_or[-1]))
            
            current = current + temp1 + temp2
            if len(current) == 8:
                if current == delimiter1 and len(data) >= 1 and data[-1] == delimiter2:
                    data.pop()
                    flag = False
                    break
                data.append(current)
                current = ""
            
            data_index += 2
            availablePixels[pixel_index][2] += 1
            frame_usage[frame_index] += 1
            if frame_usage[frame_index] >= frame_usage_limit:
                break
        
    print(data)
    data_found = "".join(chr(int(c, 2)) for c in data)
    print(data_found)

    # Store Output in File
    filehandler = open("outputs/video_steg/output.txt","w")
    filehandler.writelines(data_found)
    filehandler.close()

    return data_found

# %%
import json

def main():
    info = open('config.json')
    json_data = json.load(info)
    original_image = json_data["source"]["video_filename"]
    hennon_key = json_data["key"]["hennon_key"]
    lfsr_poly = json_data["key"]["lfsr_polynomial"]
    
    decode(original_image, hennon_key, lfsr_poly)

# %%
main()
# Out:
# [array([[[206, 206, 206],
#         [206, 206, 206],
#         [206, 206, 206],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        [[208, 208, 208],
#         [208, 208, 208],
#         [208, 208, 208],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        [[206, 209, 209],
#         [206, 209, 209],
#         [206, 209, 209],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        ...,
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]]], dtype=uint8), array([[[206, 206, 206],
#         [206, 206, 206],
#         [206, 206, 206],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        [[208, 208, 208],
#         [208, 208, 208],
#         [208, 208, 208],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        [[206, 209, 209],
#         [206, 209, 209],
#         [206, 209, 209],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        ...,
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]]], dtype=uint8), array([[[206, 206, 206],
#         [206, 206, 206],
#         [206, 206, 206],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        [[208, 208, 208],
#         [208, 208, 208],
#         [208, 208, 208],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        [[206, 209, 209],
#         [206, 209, 209],
#         [206, 209, 209],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        ...,
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]]], dtype=uint8), array([[[205, 208, 208],
#         [205, 208, 208],
#         [205, 208, 208],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        [[206, 209, 209],
#         [206, 209, 209],
#         [206, 209, 209],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        [[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        ...,
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[142, 142, 142],
#         [143, 143, 143],
#         [143, 143, 143],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[142, 142, 142],
#         [143, 143, 143],
#         [143, 143, 143],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]]], dtype=uint8), array([[[205, 208, 208],
#         [205, 208, 208],
#         [205, 208, 208],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        [[206, 209, 209],
#         [206, 209, 209],
#         [206, 209, 209],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        [[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        ...,
#
#        [[141, 144, 144],
#         [141, 144, 144],
#         [141, 144, 144],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[142, 145, 145],
#         [142, 145, 145],
#         [143, 146, 146],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[142, 145, 145],
#         [142, 145, 145],
#         [143, 146, 146],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]]], dtype=uint8), array([[[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        [[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        [[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 198, 201],
#         [202, 198, 201],
#         [202, 198, 201]],
#
#        ...,
#
#        [[142, 141, 143],
#         [142, 141, 143],
#         [142, 141, 143],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[142, 141, 143],
#         [142, 141, 143],
#         [142, 141, 143],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[142, 141, 143],
#         [142, 141, 143],
#         [142, 141, 143],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]]], dtype=uint8), array([[[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        ...,
#
#        [[140, 137, 136],
#         [140, 137, 136],
#         [140, 137, 136],
#         ...,
#         [137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138]],
#
#        [[140, 137, 136],
#         [140, 137, 136],
#         [140, 137, 136],
#         ...,
#         [137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138]],
#
#        [[141, 138, 137],
#         [141, 138, 137],
#         [141, 138, 137],
#         ...,
#         [137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138]]], dtype=uint8), array([[[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        ...,
#
#        [[140, 137, 136],
#         [140, 137, 136],
#         [140, 137, 136],
#         ...,
#         [137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138]],
#
#        [[140, 137, 136],
#         [140, 137, 136],
#         [140, 137, 136],
#         ...,
#         [137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138]],
#
#        [[141, 138, 137],
#         [141, 138, 137],
#         [141, 138, 137],
#         ...,
#         [137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138]]], dtype=uint8), array([[[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        ...,
#
#        [[140, 137, 136],
#         [140, 137, 136],
#         [140, 137, 136],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[140, 137, 136],
#         [140, 137, 136],
#         [140, 137, 136],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[141, 138, 137],
#         [141, 138, 137],
#         [141, 138, 137],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]]], dtype=uint8), array([[[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [203, 200, 201],
#         [203, 200, 201],
#         [203, 200, 201]],
#
#        [[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [203, 200, 201],
#         [203, 200, 201],
#         [203, 200, 201]],
#
#        [[204, 209, 209],
#         [204, 209, 209],
#         [204, 209, 209],
#         ...,
#         [203, 200, 201],
#         [203, 200, 201],
#         [203, 200, 201]],
#
#        ...,
#
#        [[141, 138, 137],
#         [141, 138, 137],
#         [141, 138, 137],
#         ...,
#         [136, 139, 137],
#         [136, 139, 137],
#         [136, 139, 137]],
#
#        [[140, 137, 136],
#         [140, 137, 136],
#         [140, 137, 136],
#         ...,
#         [136, 139, 137],
#         [136, 139, 137],
#         [136, 139, 137]],
#
#        [[139, 136, 135],
#         [139, 136, 135],
#         [139, 136, 135],
#         ...,
#         [136, 139, 137],
#         [136, 139, 137],
#         [136, 139, 137]]], dtype=uint8), array([[[205, 210, 210],
#         [205, 210, 210],
#         [205, 210, 210],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[205, 210, 210],
#         [205, 210, 210],
#         [205, 210, 210],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[205, 210, 210],
#         [205, 210, 210],
#         [205, 210, 210],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        ...,
#
#        [[137, 140, 140],
#         [137, 140, 140],
#         [137, 140, 140],
#         ...,
#         [137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138]],
#
#        [[139, 142, 140],
#         [139, 142, 140],
#         [139, 142, 140],
#         ...,
#         [137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138]],
#
#        [[139, 142, 140],
#         [139, 142, 140],
#         [139, 142, 140],
#         ...,
#         [137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138]]], dtype=uint8), array([[[206, 211, 211],
#         [206, 211, 211],
#         [206, 211, 211],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[206, 211, 211],
#         [206, 211, 211],
#         [206, 211, 211],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[206, 211, 211],
#         [206, 211, 211],
#         [206, 211, 211],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        ...,
#
#        [[136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135],
#         ...,
#         [136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135]],
#
#        [[136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135],
#         ...,
#         [137, 141, 136],
#         [137, 141, 136],
#         [137, 141, 136]],
#
#        [[136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135],
#         ...,
#         [137, 141, 136],
#         [137, 141, 136],
#         [137, 141, 136]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [203, 200, 201],
#         [203, 200, 201],
#         [203, 200, 201]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [203, 200, 201],
#         [203, 200, 201],
#         [203, 200, 201]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [203, 200, 201],
#         [203, 200, 201],
#         [203, 200, 201]],
#
#        ...,
#
#        [[136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135],
#         ...,
#         [135, 139, 134],
#         [135, 139, 134],
#         [135, 139, 134]],
#
#        [[136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135],
#         ...,
#         [135, 139, 134],
#         [135, 139, 134],
#         [135, 139, 134]],
#
#        [[136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135],
#         ...,
#         [135, 139, 134],
#         [135, 139, 134],
#         [135, 139, 134]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [203, 200, 201],
#         [203, 200, 201],
#         [203, 200, 201]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [203, 200, 201],
#         [203, 200, 201],
#         [203, 200, 201]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [203, 200, 201],
#         [203, 200, 201],
#         [203, 200, 201]],
#
#        ...,
#
#        [[136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135],
#         ...,
#         [135, 139, 134],
#         [135, 139, 134],
#         [135, 139, 134]],
#
#        [[136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135],
#         ...,
#         [135, 139, 134],
#         [135, 139, 134],
#         [135, 139, 134]],
#
#        [[136, 140, 135],
#         [136, 140, 135],
#         [136, 140, 135],
#         ...,
#         [135, 139, 134],
#         [135, 139, 134],
#         [135, 139, 134]]], dtype=uint8), array([[[206, 211, 209],
#         [206, 211, 209],
#         [206, 211, 209],
#         ...,
#         [200, 200, 200],
#         [203, 200, 201],
#         [203, 200, 201]],
#
#        [[206, 211, 209],
#         [206, 211, 209],
#         [206, 211, 209],
#         ...,
#         [200, 200, 200],
#         [203, 200, 201],
#         [203, 200, 201]],
#
#        [[206, 211, 209],
#         [206, 211, 209],
#         [206, 211, 209],
#         ...,
#         [200, 200, 200],
#         [203, 200, 201],
#         [203, 200, 201]],
#
#        ...,
#
#        [[134, 139, 132],
#         [134, 139, 132],
#         [134, 139, 132],
#         ...,
#         [134, 139, 132],
#         [134, 139, 132],
#         [134, 139, 132]],
#
#        [[134, 139, 132],
#         [134, 139, 132],
#         [134, 139, 132],
#         ...,
#         [134, 139, 132],
#         [134, 139, 132],
#         [134, 139, 132]],
#
#        [[134, 139, 132],
#         [134, 139, 132],
#         [134, 139, 132],
#         ...,
#         [134, 139, 132],
#         [134, 139, 132],
#         [134, 139, 132]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        ...,
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [139, 139, 139],
#         [139, 139, 139],
#         [139, 139, 139]],
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [140, 140, 140],
#         [140, 140, 140],
#         [140, 140, 140]],
#
#        [[142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142],
#         ...,
#         [142, 142, 142],
#         [142, 142, 142],
#         [142, 142, 142]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [199, 199, 199],
#         [199, 199, 199],
#         [199, 199, 199]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [199, 199, 199],
#         [199, 199, 199],
#         [199, 199, 199]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        ...,
#
#        [[139, 142, 142],
#         [139, 142, 142],
#         [139, 142, 142],
#         ...,
#         [139, 139, 139],
#         [139, 139, 139],
#         [139, 139, 139]],
#
#        [[137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138],
#         ...,
#         [139, 139, 139],
#         [139, 139, 139],
#         [139, 139, 139]],
#
#        [[137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138],
#         ...,
#         [139, 139, 139],
#         [139, 139, 139],
#         [139, 139, 139]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [199, 199, 199],
#         [199, 199, 199],
#         [199, 199, 199]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [199, 199, 199],
#         [199, 199, 199],
#         [199, 199, 199]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        ...,
#
#        [[139, 142, 142],
#         [137, 140, 140],
#         [140, 140, 140],
#         ...,
#         [139, 139, 139],
#         [139, 139, 139],
#         [139, 139, 139]],
#
#        [[139, 142, 142],
#         [137, 140, 140],
#         [140, 140, 140],
#         ...,
#         [139, 139, 139],
#         [139, 139, 139],
#         [139, 139, 139]],
#
#        [[139, 142, 142],
#         [137, 140, 140],
#         [140, 140, 140],
#         ...,
#         [139, 139, 139],
#         [139, 139, 139],
#         [139, 139, 139]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        ...,
#
#        [[139, 139, 137],
#         [139, 139, 137],
#         [139, 139, 137],
#         ...,
#         [140, 139, 141],
#         [142, 142, 142],
#         [142, 142, 142]],
#
#        [[139, 139, 137],
#         [139, 139, 137],
#         [139, 139, 137],
#         ...,
#         [140, 139, 141],
#         [142, 142, 142],
#         [142, 142, 142]],
#
#        [[139, 139, 137],
#         [139, 139, 137],
#         [139, 139, 137],
#         ...,
#         [140, 139, 141],
#         [142, 142, 142],
#         [142, 142, 142]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        ...,
#
#        [[139, 139, 137],
#         [139, 139, 137],
#         [139, 139, 137],
#         ...,
#         [140, 139, 141],
#         [142, 142, 142],
#         [142, 142, 142]],
#
#        [[139, 139, 137],
#         [139, 139, 137],
#         [139, 139, 137],
#         ...,
#         [140, 139, 141],
#         [142, 142, 142],
#         [142, 142, 142]],
#
#        [[139, 139, 137],
#         [139, 139, 137],
#         [139, 139, 137],
#         ...,
#         [140, 139, 141],
#         [142, 142, 142],
#         [142, 142, 142]]], dtype=uint8), array([[[206, 211, 211],
#         [206, 211, 211],
#         [206, 211, 211],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[206, 211, 211],
#         [206, 211, 211],
#         [206, 211, 211],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[206, 211, 211],
#         [206, 211, 211],
#         [206, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        ...,
#
#        [[139, 142, 140],
#         [139, 142, 140],
#         [139, 142, 140],
#         ...,
#         [142, 141, 143],
#         [142, 142, 142],
#         [142, 142, 142]],
#
#        [[139, 142, 140],
#         [139, 142, 140],
#         [139, 142, 140],
#         ...,
#         [142, 141, 143],
#         [142, 142, 142],
#         [142, 142, 142]],
#
#        [[139, 142, 140],
#         [139, 142, 140],
#         [139, 142, 140],
#         ...,
#         [142, 141, 143],
#         [142, 142, 142],
#         [142, 142, 142]]], dtype=uint8), array([[[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        ...,
#
#        [[137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138],
#         ...,
#         [143, 142, 144],
#         [143, 143, 143],
#         [143, 143, 143]],
#
#        [[137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138],
#         ...,
#         [143, 142, 144],
#         [143, 143, 143],
#         [143, 143, 143]],
#
#        [[137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138],
#         ...,
#         [143, 142, 144],
#         [143, 143, 143],
#         [143, 143, 143]]], dtype=uint8), array([[[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [201, 201, 201]],
#
#        ...,
#
#        [[137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138],
#         ...,
#         [143, 143, 143],
#         [143, 143, 143],
#         [143, 143, 143]],
#
#        [[137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138],
#         ...,
#         [143, 143, 143],
#         [143, 143, 141],
#         [143, 143, 141]],
#
#        [[137, 140, 138],
#         [137, 140, 138],
#         [137, 140, 138],
#         ...,
#         [143, 143, 143],
#         [143, 143, 141],
#         [143, 143, 141]]], dtype=uint8), array([[[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [202, 202, 202],
#         [199, 202, 202],
#         [200, 203, 203]],
#
#        [[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [202, 202, 202],
#         [199, 202, 202],
#         [200, 203, 203]],
#
#        [[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [199, 202, 202],
#         [199, 202, 202],
#         [200, 203, 203]],
#
#        ...,
#
#        [[134, 138, 133],
#         [134, 138, 133],
#         [134, 138, 133],
#         ...,
#         [143, 143, 143],
#         [143, 143, 143],
#         [143, 143, 143]],
#
#        [[133, 136, 134],
#         [134, 137, 135],
#         [135, 138, 136],
#         ...,
#         [143, 143, 143],
#         [143, 143, 143],
#         [143, 143, 143]],
#
#        [[133, 136, 134],
#         [134, 137, 135],
#         [135, 138, 136],
#         ...,
#         [143, 143, 143],
#         [143, 143, 143],
#         [143, 143, 143]]], dtype=uint8), array([[[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [202, 202, 202],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        [[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [202, 202, 202],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        [[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [199, 202, 202],
#         [198, 201, 201],
#         [199, 202, 202]],
#
#        ...,
#
#        [[127, 131, 126],
#         [127, 131, 126],
#         [127, 131, 126],
#         ...,
#         [140, 140, 140],
#         [140, 140, 140],
#         [140, 140, 140]],
#
#        [[127, 132, 125],
#         [127, 132, 125],
#         [127, 132, 125],
#         ...,
#         [140, 140, 140],
#         [140, 140, 140],
#         [140, 140, 140]],
#
#        [[126, 131, 124],
#         [126, 131, 124],
#         [126, 131, 124],
#         ...,
#         [140, 140, 140],
#         [140, 140, 140],
#         [140, 140, 140]]], dtype=uint8), array([[[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [202, 202, 202],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        [[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [202, 202, 202],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        [[207, 210, 210],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [199, 202, 202],
#         [198, 201, 201],
#         [199, 202, 202]],
#
#        ...,
#
#        [[127, 131, 126],
#         [127, 131, 126],
#         [127, 131, 126],
#         ...,
#         [140, 140, 140],
#         [140, 140, 140],
#         [140, 140, 140]],
#
#        [[127, 132, 125],
#         [127, 132, 125],
#         [127, 132, 125],
#         ...,
#         [140, 140, 140],
#         [140, 140, 140],
#         [140, 140, 140]],
#
#        [[126, 131, 124],
#         [126, 131, 124],
#         [126, 131, 124],
#         ...,
#         [140, 140, 140],
#         [140, 140, 140],
#         [140, 140, 140]]], dtype=uint8), array([[[206, 209, 209],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [199, 202, 202],
#         [199, 202, 202],
#         [199, 202, 202]],
#
#        [[206, 209, 209],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [199, 202, 202],
#         [199, 202, 202],
#         [199, 202, 202]],
#
#        [[206, 209, 209],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [199, 202, 202],
#         [199, 202, 202],
#         [199, 202, 202]],
#
#        ...,
#
#        [[126, 132, 122],
#         [126, 132, 122],
#         [126, 132, 122],
#         ...,
#         [139, 139, 139],
#         [139, 139, 139],
#         [139, 139, 139]],
#
#        [[126, 132, 122],
#         [126, 132, 122],
#         [126, 132, 122],
#         ...,
#         [139, 139, 139],
#         [139, 139, 139],
#         [139, 139, 139]],
#
#        [[126, 132, 122],
#         [126, 132, 122],
#         [126, 132, 122],
#         ...,
#         [139, 139, 139],
#         [139, 139, 139],
#         [139, 139, 139]]], dtype=uint8), array([[[206, 209, 209],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [204, 201, 202],
#         [199, 202, 202],
#         [199, 202, 202]],
#
#        [[206, 209, 209],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [205, 202, 203],
#         [199, 202, 202],
#         [199, 202, 202]],
#
#        [[206, 209, 209],
#         [207, 210, 210],
#         [207, 210, 210],
#         ...,
#         [203, 203, 203],
#         [199, 202, 202],
#         [199, 202, 202]],
#
#        ...,
#
#        [[133, 137, 132],
#         [133, 137, 132],
#         [133, 137, 132],
#         ...,
#         [133, 137, 132],
#         [133, 137, 132],
#         [133, 137, 132]],
#
#        [[133, 137, 132],
#         [133, 137, 132],
#         [133, 137, 132],
#         ...,
#         [133, 137, 132],
#         [133, 137, 132],
#         [133, 137, 132]],
#
#        [[133, 137, 132],
#         [133, 137, 132],
#         [133, 137, 132],
#         ...,
#         [133, 137, 132],
#         [133, 137, 132],
#         [133, 137, 132]]], dtype=uint8), array([[[208, 211, 209],
#         [208, 211, 209],
#         [208, 211, 209],
#         ...,
#         [200, 200, 200],
#         [203, 200, 201],
#         [204, 201, 202]],
#
#        [[208, 211, 209],
#         [208, 211, 209],
#         [208, 211, 209],
#         ...,
#         [200, 200, 200],
#         [203, 200, 201],
#         [204, 201, 202]],
#
#        [[208, 211, 209],
#         [208, 211, 209],
#         [208, 211, 209],
#         ...,
#         [201, 201, 201],
#         [203, 200, 201],
#         [204, 201, 202]],
#
#        ...,
#
#        [[129, 130, 125],
#         [130, 131, 126],
#         [131, 132, 127],
#         ...,
#         [143, 143, 143],
#         [143, 143, 143],
#         [143, 143, 143]],
#
#        [[130, 131, 126],
#         [131, 132, 127],
#         [131, 132, 127],
#         ...,
#         [143, 143, 143],
#         [143, 143, 143],
#         [143, 143, 143]],
#
#        [[131, 132, 127],
#         [131, 132, 127],
#         [131, 132, 127],
#         ...,
#         [143, 143, 143],
#         [143, 143, 143],
#         [143, 143, 143]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [200, 200, 200],
#         [203, 200, 201],
#         [204, 201, 202]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [203, 200, 201],
#         [204, 201, 202]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [203, 203, 203],
#         [203, 200, 201],
#         [205, 202, 203]],
#
#        ...,
#
#        [[128, 129, 124],
#         [128, 129, 124],
#         [128, 129, 124],
#         ...,
#         [136, 139, 137],
#         [136, 139, 137],
#         [136, 139, 137]],
#
#        [[128, 129, 124],
#         [128, 129, 124],
#         [128, 129, 124],
#         ...,
#         [136, 139, 137],
#         [136, 139, 137],
#         [136, 139, 137]],
#
#        [[128, 129, 124],
#         [128, 129, 124],
#         [128, 129, 124],
#         ...,
#         [136, 139, 137],
#         [136, 139, 137],
#         [136, 139, 137]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [196, 199, 199],
#         [197, 197, 197],
#         [200, 200, 200]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [196, 199, 199],
#         [197, 197, 197],
#         [200, 200, 200]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [197, 200, 200],
#         [199, 199, 199],
#         [201, 201, 201]],
#
#        ...,
#
#        [[130, 128, 124],
#         [130, 128, 124],
#         [130, 128, 124],
#         ...,
#         [133, 133, 133],
#         [132, 132, 132],
#         [132, 132, 132]],
#
#        [[130, 128, 124],
#         [130, 128, 124],
#         [130, 128, 124],
#         ...,
#         [133, 133, 133],
#         [133, 133, 133],
#         [133, 133, 133]],
#
#        [[130, 128, 124],
#         [130, 128, 124],
#         [130, 128, 124],
#         ...,
#         [133, 133, 133],
#         [133, 133, 133],
#         [133, 133, 133]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [197, 200, 200],
#         [199, 199, 199],
#         [201, 201, 201]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [197, 200, 200],
#         [199, 199, 199],
#         [201, 201, 201]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [197, 200, 200],
#         [199, 199, 199],
#         [201, 201, 201]],
#
#        ...,
#
#        [[130, 128, 124],
#         [130, 128, 124],
#         [130, 128, 124],
#         ...,
#         [133, 133, 133],
#         [132, 132, 132],
#         [132, 132, 132]],
#
#        [[130, 128, 124],
#         [130, 128, 124],
#         [130, 128, 124],
#         ...,
#         [133, 133, 133],
#         [133, 133, 133],
#         [133, 133, 133]],
#
#        [[130, 128, 124],
#         [130, 128, 124],
#         [130, 128, 124],
#         ...,
#         [133, 133, 133],
#         [133, 133, 133],
#         [133, 133, 133]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        ...,
#
#        [[130, 128, 124],
#         [130, 128, 124],
#         [130, 128, 124],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122]],
#
#        [[130, 128, 124],
#         [130, 128, 124],
#         [130, 128, 124],
#         ...,
#         [123, 123, 123],
#         [123, 123, 123],
#         [123, 123, 123]],
#
#        [[130, 128, 124],
#         [130, 128, 124],
#         [130, 128, 124],
#         ...,
#         [123, 123, 123],
#         [123, 123, 123],
#         [123, 123, 123]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        ...,
#
#        [[126, 127, 122],
#         [126, 127, 122],
#         [126, 127, 122],
#         ...,
#         [116, 116, 116],
#         [115, 115, 115],
#         [114, 114, 114]],
#
#        [[126, 127, 122],
#         [126, 127, 122],
#         [126, 127, 122],
#         ...,
#         [116, 116, 116],
#         [115, 115, 115],
#         [114, 114, 114]],
#
#        [[128, 129, 124],
#         [128, 129, 124],
#         [128, 129, 124],
#         ...,
#         [116, 116, 116],
#         [115, 115, 115],
#         [114, 114, 114]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [199, 199, 199],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [199, 199, 199],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [200, 200, 200],
#         [200, 200, 200],
#         [200, 200, 200]],
#
#        ...,
#
#        [[128, 129, 124],
#         [128, 129, 124],
#         [128, 129, 124],
#         ...,
#         [114, 114, 114],
#         [114, 114, 114],
#         [114, 114, 114]],
#
#        [[128, 129, 124],
#         [128, 129, 124],
#         [128, 129, 124],
#         ...,
#         [114, 114, 114],
#         [114, 114, 114],
#         [114, 114, 114]],
#
#        [[128, 129, 124],
#         [128, 129, 124],
#         [128, 129, 124],
#         ...,
#         [114, 114, 114],
#         [114, 114, 114],
#         [114, 114, 114]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        ...,
#
#        [[131, 132, 127],
#         [131, 132, 127],
#         [131, 132, 127],
#         ...,
#         [110, 110, 110],
#         [110, 110, 110],
#         [110, 110, 110]],
#
#        [[130, 131, 126],
#         [130, 131, 126],
#         [130, 131, 126],
#         ...,
#         [110, 110, 110],
#         [110, 110, 110],
#         [110, 110, 110]],
#
#        [[129, 130, 125],
#         [129, 130, 125],
#         [129, 130, 125],
#         ...,
#         [110, 110, 110],
#         [110, 110, 110],
#         [110, 110, 110]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        ...,
#
#        [[133, 135, 128],
#         [133, 135, 128],
#         [133, 135, 128],
#         ...,
#         [107, 104, 105],
#         [107, 104, 105],
#         [107, 104, 105]],
#
#        [[132, 133, 128],
#         [132, 133, 128],
#         [132, 133, 128],
#         ...,
#         [107, 104, 105],
#         [107, 104, 105],
#         [107, 104, 105]],
#
#        [[131, 132, 127],
#         [131, 132, 127],
#         [131, 132, 127],
#         ...,
#         [107, 104, 105],
#         [107, 104, 105],
#         [107, 104, 105]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        ...,
#
#        [[133, 135, 128],
#         [133, 135, 128],
#         [133, 135, 128],
#         ...,
#         [107, 104, 105],
#         [107, 104, 105],
#         [107, 104, 105]],
#
#        [[132, 133, 128],
#         [132, 133, 128],
#         [132, 133, 128],
#         ...,
#         [107, 104, 105],
#         [107, 104, 105],
#         [107, 104, 105]],
#
#        [[131, 132, 127],
#         [131, 132, 127],
#         [131, 132, 127],
#         ...,
#         [107, 104, 105],
#         [107, 104, 105],
#         [107, 104, 105]]], dtype=uint8), array([[[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        [[208, 211, 211],
#         [208, 211, 211],
#         [208, 211, 211],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        ...,
#
#        [[133, 138, 131],
#         [133, 138, 131],
#         [133, 138, 131],
#         ...,
#         [105, 102, 103],
#         [105, 102, 103],
#         [105, 102, 103]],
#
#        [[133, 138, 131],
#         [134, 139, 132],
#         [134, 139, 132],
#         ...,
#         [105, 102, 103],
#         [105, 102, 103],
#         [105, 102, 103]],
#
#        [[132, 137, 130],
#         [133, 138, 131],
#         [134, 139, 132],
#         ...,
#         [105, 102, 103],
#         [105, 102, 103],
#         [105, 102, 103]]], dtype=uint8), array([[[211, 214, 214],
#         [212, 215, 215],
#         [212, 215, 215],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        [[211, 214, 214],
#         [212, 215, 215],
#         [212, 215, 215],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        [[208, 211, 211],
#         [210, 213, 213],
#         [210, 213, 213],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        ...,
#
#        [[130, 135, 128],
#         [130, 135, 128],
#         [130, 135, 128],
#         ...,
#         [103, 100, 101],
#         [103, 100, 101],
#         [103, 100, 101]],
#
#        [[130, 135, 128],
#         [130, 135, 128],
#         [130, 135, 128],
#         ...,
#         [103, 100, 101],
#         [103, 100, 101],
#         [103, 100, 101]],
#
#        [[130, 135, 128],
#         [130, 135, 128],
#         [130, 135, 128],
#         ...,
#         [103, 100, 101],
#         [103, 100, 101],
#         [103, 100, 101]]], dtype=uint8), array([[[213, 216, 216],
#         [213, 216, 216],
#         [213, 216, 216],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        [[213, 216, 216],
#         [213, 216, 216],
#         [213, 216, 216],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        [[212, 215, 215],
#         [211, 214, 214],
#         [212, 215, 215],
#         ...,
#         [202, 198, 201],
#         [203, 199, 202],
#         [203, 199, 202]],
#
#        ...,
#
#        [[132, 137, 130],
#         [132, 137, 130],
#         [132, 137, 130],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]],
#
#        [[132, 137, 130],
#         [132, 137, 130],
#         [132, 137, 130],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]],
#
#        [[132, 137, 130],
#         [132, 137, 130],
#         [132, 137, 130],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]]], dtype=uint8), array([[[213, 216, 216],
#         [213, 216, 216],
#         [213, 216, 216],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[213, 216, 216],
#         [213, 216, 216],
#         [213, 216, 216],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[213, 216, 216],
#         [213, 216, 216],
#         [213, 216, 216],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        ...,
#
#        [[132, 137, 130],
#         [132, 137, 130],
#         [132, 137, 130],
#         ...,
#         [ 99,  96,  97],
#         [ 99,  96,  97],
#         [ 99,  96,  97]],
#
#        [[132, 137, 130],
#         [132, 137, 130],
#         [132, 137, 130],
#         ...,
#         [ 99,  96,  97],
#         [ 99,  96,  97],
#         [ 99,  96,  97]],
#
#        [[132, 137, 130],
#         [132, 137, 130],
#         [132, 137, 130],
#         ...,
#         [ 99,  96,  97],
#         [ 99,  96,  97],
#         [ 99,  96,  97]]], dtype=uint8), array([[[213, 216, 216],
#         [213, 216, 216],
#         [213, 216, 216],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[213, 216, 216],
#         [213, 216, 216],
#         [213, 216, 216],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[213, 216, 216],
#         [213, 216, 216],
#         [213, 216, 216],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        ...,
#
#        [[133, 138, 131],
#         [133, 138, 131],
#         [133, 138, 131],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]],
#
#        [[133, 138, 131],
#         [133, 138, 131],
#         [133, 138, 131],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]],
#
#        [[133, 138, 131],
#         [133, 138, 131],
#         [133, 138, 131],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]]], dtype=uint8), array([[[213, 216, 216],
#         [213, 216, 216],
#         [213, 216, 216],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[213, 216, 216],
#         [213, 216, 216],
#         [213, 216, 216],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        [[213, 216, 216],
#         [213, 216, 216],
#         [213, 216, 216],
#         ...,
#         [202, 199, 200],
#         [202, 199, 200],
#         [202, 199, 200]],
#
#        ...,
#
#        [[133, 138, 131],
#         [133, 138, 131],
#         [133, 138, 131],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]],
#
#        [[133, 138, 131],
#         [133, 138, 131],
#         [133, 138, 131],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]],
#
#        [[133, 138, 131],
#         [133, 138, 131],
#         [133, 138, 131],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]]], dtype=uint8), array([[[214, 217, 217],
#         [215, 218, 218],
#         [215, 218, 218],
#         ...,
#         [199, 199, 199],
#         [199, 199, 199],
#         [199, 199, 199]],
#
#        [[214, 217, 217],
#         [215, 218, 218],
#         [215, 218, 218],
#         ...,
#         [199, 199, 199],
#         [199, 199, 199],
#         [199, 199, 199]],
#
#        [[214, 217, 217],
#         [215, 218, 218],
#         [215, 218, 218],
#         ...,
#         [199, 199, 199],
#         [199, 199, 199],
#         [199, 199, 199]],
#
#        ...,
#
#        [[134, 139, 132],
#         [134, 139, 132],
#         [134, 139, 132],
#         ...,
#         [100,  97,  98],
#         [100,  97,  98],
#         [100,  97,  98]],
#
#        [[134, 139, 132],
#         [134, 139, 132],
#         [134, 139, 132],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]],
#
#        [[134, 139, 132],
#         [134, 139, 132],
#         [134, 139, 132],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]]], dtype=uint8), array([[[214, 217, 217],
#         [215, 218, 218],
#         [215, 218, 218],
#         ...,
#         [199, 199, 199],
#         [199, 199, 199],
#         [199, 199, 199]],
#
#        [[214, 217, 217],
#         [215, 218, 218],
#         [215, 218, 218],
#         ...,
#         [199, 199, 199],
#         [199, 199, 199],
#         [199, 199, 199]],
#
#        [[214, 217, 217],
#         [215, 218, 218],
#         [215, 218, 218],
#         ...,
#         [199, 199, 199],
#         [199, 199, 199],
#         [199, 199, 199]],
#
#        ...,
#
#        [[129, 134, 127],
#         [129, 134, 127],
#         [129, 134, 127],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]],
#
#        [[129, 134, 127],
#         [129, 134, 127],
#         [129, 134, 127],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]],
#
#        [[129, 134, 127],
#         [129, 134, 127],
#         [129, 134, 127],
#         ...,
#         [102,  99, 100],
#         [102,  99, 100],
#         [102,  99, 100]]], dtype=uint8), array([[[213, 216, 216],
#         [214, 217, 217],
#         [214, 217, 217],
#         ...,
#         [201, 198, 199],
#         [201, 198, 199],
#         [201, 198, 199]],
#
#        [[213, 216, 216],
#         [214, 217, 217],
#         [214, 217, 217],
#         ...,
#         [201, 198, 199],
#         [201, 198, 199],
#         [201, 198, 199]],
#
#        [[213, 216, 216],
#         [214, 217, 217],
#         [214, 217, 217],
#         ...,
#         [201, 198, 199],
#         [201, 198, 199],
#         [201, 198, 199]],
#
#        ...,
#
#        [[125, 130, 123],
#         [125, 130, 123],
#         [125, 130, 123],
#         ...,
#         [ 99,  96,  97],
#         [ 99,  96,  97],
#         [ 99,  96,  97]],
#
#        [[125, 130, 123],
#         [125, 130, 123],
#         [125, 130, 123],
#         ...,
#         [ 99,  96,  97],
#         [ 99,  96,  97],
#         [ 99,  96,  97]],
#
#        [[125, 130, 123],
#         [125, 130, 123],
#         [125, 130, 123],
#         ...,
#         [ 99,  96,  97],
#         [ 99,  96,  97],
#         [ 99,  96,  97]]], dtype=uint8), array([[[213, 216, 216],
#         [214, 217, 217],
#         [214, 217, 217],
#         ...,
#         [201, 198, 199],
#         [201, 198, 199],
#         [201, 198, 199]],
#
#        [[213, 216, 216],
# ...
# pixel selected 315735
# pixel selected 315990
# pixel selected 316245
# pixel selected 316500
# pixel selected 316755
# pixel selected 317010
# pixel selected 317265
# pixel selected 317520
# pixel selected 317775
# pixel selected 318030
# pixel selected 318285
# pixel selected 318540
# pixel selected 318795
# pixel selected 319050
# pixel selected 319305
# pixel selected 319560
# pixel selected 319815
# pixel selected 320070
# pixel selected 320325
# pixel selected 320580
# pixel selected 320835
# pixel selected 321090
# pixel selected 321345
# pixel selected 321600
# pixel selected 321855
# pixel selected 322110
# pixel selected 322365
# pixel selected 322620
# pixel selected 322875
# pixel selected 323130
# pixel selected 323385
# pixel selected 323640
# pixel selected 323895
# pixel selected 324150
# pixel selected 324405
# pixel selected 324660
# pixel selected 324915
# pixel selected 325170
# pixel selected 325425
# pixel selected 325680
# pixel selected 325935
# pixel selected 326190
# pixel selected 326445
# pixel selected 326700
# pixel selected 326955
# pixel selected 327210
# pixel selected 327465
# pixel selected 327720
# pixel selected 327975
# pixel selected 328230
# pixel selected 328485
# pixel selected 328740
# pixel selected 328995
# pixel selected 329250
# pixel selected 329505
# pixel selected 329760
# pixel selected 330015
# pixel selected 330270
# pixel selected 330525
# pixel selected 330780
# pixel selected 331035
# pixel selected 331290
# pixel selected 331545
# pixel selected 331800
# pixel selected 332055
# pixel selected 332310
# pixel selected 332565
# pixel selected 332820
# pixel selected 333075
# pixel selected 333330
# pixel selected 333585
# pixel selected 333840
# pixel selected 334095
# pixel selected 334350
# pixel selected 334605
# pixel selected 334860
# pixel selected 335115
# pixel selected 335370
# pixel selected 335625
# pixel selected 335880
# pixel selected 336135
# pixel selected 336390
# pixel selected 336645
# pixel selected 336900
# pixel selected 337155
# pixel selected 337410
# pixel selected 337665
# pixel selected 337920
# pixel selected 338175
# pixel selected 338430
# pixel selected 338685
# pixel selected 338940
# pixel selected 339195
# pixel selected 339450
# pixel selected 339705
# pixel selected 339960
# pixel selected 340215
# pixel selected 340470
# pixel selected 340725
# pixel selected 340980
# pixel selected 341235
# pixel selected 341490
# pixel selected 341745
# pixel selected 342000
# pixel selected 342255
# pixel selected 342510
# pixel selected 342765
# pixel selected 343020
# pixel selected 343275
# pixel selected 343530
# pixel selected 343785
# pixel selected 344040
# pixel selected 344295
# pixel selected 344550
# pixel selected 344805
# pixel selected 345060
# pixel selected 345315
# pixel selected 345570
# pixel selected 345825
# pixel selected 346080
# pixel selected 346335
# pixel selected 346590
# pixel selected 346845
# pixel selected 347100
# pixel selected 347355
# pixel selected 347610
# pixel selected 347865
# pixel selected 348120
# pixel selected 348375
# pixel selected 348630
# pixel selected 348885
# pixel selected 349140
# pixel selected 349395
# pixel selected 349650
# pixel selected 349905
# pixel selected 350160
# pixel selected 350415
# pixel selected 350670
# pixel selected 350925
# pixel selected 351180
# pixel selected 351435
# pixel selected 351690
# pixel selected 351945
# pixel selected 352200
# pixel selected 352455
# pixel selected 352710
# pixel selected 352965
# pixel selected 353220
# pixel selected 353475
# pixel selected 353730
# pixel selected 353985
# pixel selected 354240
# pixel selected 354495
# pixel selected 354750
# pixel selected 355005
# pixel selected 355260
# pixel selected 355515
# pixel selected 355770
# pixel selected 356025
# pixel selected 356280
# pixel selected 356535
# pixel selected 356790
# pixel selected 357045
# pixel selected 357300
# pixel selected 357555
# pixel selected 357810
# pixel selected 358065
# pixel selected 358320
# pixel selected 358575
# pixel selected 358830
# pixel selected 359085
# pixel selected 359340
# pixel selected 359595
# pixel selected 359850
# pixel selected 360105
# pixel selected 360360
# pixel selected 360615
# pixel selected 360870
# pixel selected 361125
# pixel selected 361380
# pixel selected 361635
# pixel selected 361890
# pixel selected 362145
# pixel selected 362400
# pixel selected 362655
# pixel selected 362910
# pixel selected 363165
# pixel selected 363420
# pixel selected 363675
# pixel selected 363930
# pixel selected 364185
# pixel selected 364440
# pixel selected 364695
# pixel selected 364950
# pixel selected 365205
# pixel selected 365460
# pixel selected 365715
# pixel selected 365970
# pixel selected 366225
# pixel selected 366480
# pixel selected 366735
# pixel selected 366990
# pixel selected 367245
# pixel selected 367500
# pixel selected 367755
# pixel selected 368010
# pixel selected 368265
# pixel selected 368520
# pixel selected 368775
# pixel selected 369030
# pixel selected 369285
# pixel selected 369540
# pixel selected 369795
# pixel selected 370050
# pixel selected 370305
# pixel selected 370560
# pixel selected 370815
# pixel selected 371070
# pixel selected 371325
# pixel selected 371580
# pixel selected 371835
# pixel selected 372090
# pixel selected 372345
# pixel selected 372600
# pixel selected 372855
# pixel selected 373110
# pixel selected 373365
# pixel selected 373620
# pixel selected 373875
# pixel selected 374130
# pixel selected 374385
# pixel selected 374640
# pixel selected 374895
# pixel selected 375150
# pixel selected 375405
# pixel selected 375660
# pixel selected 375915
# pixel selected 376170
# pixel selected 376425
# pixel selected 376680
# pixel selected 376935
# pixel selected 377190
# pixel selected 377445
# pixel selected 377700
# pixel selected 377955
# pixel selected 378210
# pixel selected 378465
# pixel selected 378720
# pixel selected 378975
# pixel selected 379230
# pixel selected 379485
# pixel selected 379740
# pixel selected 379995
# pixel selected 380250
# pixel selected 380505
# pixel selected 380760
# pixel selected 381015
# pixel selected 381270
# pixel selected 381525
# pixel selected 381780
# pixel selected 382035
# pixel selected 382290
# pixel selected 382545
# pixel selected 382800
# pixel selected 383055
# pixel selected 383310
# pixel selected 383565
# pixel selected 383820
# pixel selected 384075
# pixel selected 384330
# pixel selected 384585
# pixel selected 384840
# pixel selected 385095
# pixel selected 385350
# pixel selected 385605
# pixel selected 385860
# pixel selected 386115
# pixel selected 386370
# pixel selected 386625
# pixel selected 386880
# pixel selected 387135
# pixel selected 387390
# pixel selected 387645
# pixel selected 387900
# pixel selected 388155
# pixel selected 388410
# pixel selected 388665
# pixel selected 388920
# pixel selected 389175
# pixel selected 389430
# pixel selected 389685
# pixel selected 389940
# pixel selected 390195
# pixel selected 390450
# pixel selected 390705
# pixel selected 390960
# pixel selected 391215
# pixel selected 391470
# pixel selected 391725
# pixel selected 391980
# pixel selected 392235
# pixel selected 392490
# pixel selected 392745
# pixel selected 393000
# pixel selected 393255
# pixel selected 393510
# pixel selected 393765
# pixel selected 394020
# pixel selected 394275
# pixel selected 394530
# pixel selected 394785
# pixel selected 395040
# pixel selected 395295
# pixel selected 395550
# pixel selected 395805
# pixel selected 396060
# pixel selected 396315
# pixel selected 396570
# pixel selected 396825
# pixel selected 397080
# pixel selected 397335
# pixel selected 397590
# pixel selected 397845
# pixel selected 398100
# pixel selected 398355
# pixel selected 398610
# pixel selected 398865
# pixel selected 399120
# pixel selected 399375
# pixel selected 399630
# pixel selected 399885
# pixel selected 400140
# pixel selected 400395
# pixel selected 400650
# pixel selected 400905
# pixel selected 401160
# pixel selected 401415
# pixel selected 401670
# pixel selected 401925
# pixel selected 402180
# pixel selected 402435
# pixel selected 402690
# pixel selected 402945
# pixel selected 403200
# pixel selected 403455
# pixel selected 403710
# pixel selected 403965
# pixel selected 404220
# pixel selected 404475
# pixel selected 404730
# pixel selected 404985
# pixel selected 405240
# pixel selected 405495
# pixel selected 405750
# pixel selected 406005
# pixel selected 406260
# pixel selected 406515
# pixel selected 406770
# pixel selected 407025
# pixel selected 407280
# pixel selected 407535
# pixel selected 407790
# pixel selected 408045
# pixel selected 408300
# pixel selected 408555
# pixel selected 408810
# pixel selected 409065
# pixel selected 409320
# pixel selected 409575
# pixel selected 409830
# pixel selected 410085
# pixel selected 410340
# pixel selected 410595
# pixel selected 410850
# pixel selected 411105
# pixel selected 411360
# pixel selected 411615
# pixel selected 411870
# pixel selected 412125
# pixel selected 412380
# pixel selected 412635
# pixel selected 412890
# pixel selected 413145
# pixel selected 413400
# pixel selected 413655
# pixel selected 413910
# pixel selected 414165
# pixel selected 414420
# pixel selected 414675
# pixel selected 414930
# pixel selected 415185
# pixel selected 415440
# pixel selected 415695
# pixel selected 415950
# pixel selected 416205
# pixel selected 416460
# pixel selected 416715
# pixel selected 416970
# pixel selected 417225
# pixel selected 417480
# pixel selected 417735
# pixel selected 417990
# pixel selected 418245
# pixel selected 418500
# pixel selected 418755
# pixel selected 419010
# pixel selected 419265
# pixel selected 419520
# pixel selected 419775
# pixel selected 420030
# pixel selected 420285
# pixel selected 420540
# pixel selected 420795
# pixel selected 421050
# pixel selected 421305
# pixel selected 421560
# pixel selected 421815
# pixel selected 422070
# pixel selected 422325
# pixel selected 422580
# pixel selected 422835
# pixel selected 423090
# pixel selected 423345
# pixel selected 423600
# pixel selected 423855
# pixel selected 424110
# pixel selected 424365
# pixel selected 424620
# pixel selected 424875
# pixel selected 425130
# pixel selected 425385
# pixel selected 425640
# pixel selected 425895
# pixel selected 426150
# pixel selected 426405
# pixel selected 426660
# pixel selected 426915
# pixel selected 427170
# pixel selected 427425
# pixel selected 427680
# pixel selected 427935
# pixel selected 428190
# pixel selected 428445
# pixel selected 428700
# pixel selected 428955
# pixel selected 429210
# pixel selected 429465
# pixel selected 429720
# pixel selected 429975
# pixel selected 430230
# pixel selected 430485
# pixel selected 430740
# pixel selected 430995
# pixel selected 431250
# pixel selected 431505
# pixel selected 431760
# pixel selected 432015
# pixel selected 432270
# pixel selected 432525
# pixel selected 432780
# pixel selected 433035
# pixel selected 433290
# pixel selected 433545
# pixel selected 433800
# pixel selected 434055
# pixel selected 434310
# pixel selected 434565
# pixel selected 434820
# pixel selected 435075
# pixel selected 435330
# pixel selected 435585
# pixel selected 435840
# pixel selected 436095
# pixel selected 436350
# pixel selected 436605
# pixel selected 436860
# pixel selected 437115
# pixel selected 437370
# pixel selected 437625
# pixel selected 437880
# pixel selected 438135
# pixel selected 438390
# pixel selected 438645
# pixel selected 438900
# ['01010100', '01101000', '01100101', '00100000', '01001100', '01101111', '01110011', '01110100', '00100000', '01000011', '01101001', '01110100', '01111001', '00001010', '00001010', '01000100', '01100101', '01100101', '01110000', '00100000', '01101001', '01101110', '00100000', '01110100', '01101000', '01100101', '00100000', '01101000', '01100101', '01100001', '01110010', '01110100', '00100000', '01101111', '01100110', '00100000', '01110100', '01101000', '01100101', '00100000', '01000001', '01101101', '01100001', '01111010', '01101111', '01101110', '00100000', '01110010', '01100001', '01101001', '01101110', '01100110', '01101111', '01110010', '01100101', '01110011', '01110100', '00101100', '00100000', '01110100', '01101000', '01100101', '01110010', '01100101', '00100000', '01101100', '01101001', '01100101', '01110011', '00100000', '01100001', '00100000', '01101100', '01101111', '01110011', '01110100', '00100000', '01100011', '01101001', '01110100', '01111001', '00101110', '00100000', '00001010', '01001001', '01110100', '00100000', '01101001', '01110011', '00100000', '01110011', '01100001', '01101001', '01100100', '00100000', '01110100', '01101111', '00100000', '01100010', '01100101', '00100000', '01100110', '01101001', '01101100', '01101100', '01100101', '01100100', '00100000', '01110111', '01101001', '01110100', '01101000', '00100000', '01100111', '01101111', '01101100', '01100100', '00100000', '01100001', '01101110', '01100100', '00100000', '01110100', '01110010', '01100101', '01100001', '01110011', '01110101', '01110010', '01100101', '01110011', '00100000', '01100010', '01100101', '01111001', '01101111', '01101110', '01100100', '00100000', '01100011', '01101111', '01101101', '01110000', '01100001', '01110010', '01100101', '00101110', '00100000', '00001010', '01001101', '01100001', '01101110', '01111001', '00100000', '01101000', '01100001', '01110110', '01100101', '00100000', '01110011', '01100101', '01100001', '01110010', '01100011', '01101000', '01100101', '01100100', '00100000', '01100110', '01101111', '01110010', '00100000', '01101001', '01110100', '00101100', '00100000', '01100010', '01110101', '01110100', '00100000', '01101110', '01101111', '01101110', '01100101', '00100000', '01101000', '01100001', '01110110', '01100101', '00100000', '01100101', '01110110', '01100101', '01110010', '00100000', '01110010', '01100101', '01110100', '01110101', '01110010', '01101110', '01100101', '01100100', '00101110', '00001010', '00001010', '01001111', '01101110', '01100101', '00100000', '01100100', '01100001', '01111001', '00101100', '00100000', '01100001', '00100000', '01111001', '01101111', '01110101', '01101110', '01100111', '00100000', '01110111', '01101111', '01101101', '01100001', '01101110', '00100000', '01101110', '01100001', '01101101', '01100101', '01100100', '00100000', '01000001', '01101110', '01111001', '01100001', '00100000', '01110011', '01100101', '01110100', '00100000', '01101111', '01110101', '01110100', '00100000', '01110100', '01101111', '00100000', '01100110', '01101001', '01101110', '01100100', '00100000', '01110100', '01101000', '01100101', '00100000', '01101100', '01101111', '01110011', '01110100', '00100000', '01100011', '01101001', '01110100', '01111001', '00101110', '00100000', '00001010', '01010011', '01101000', '01100101', '00100000', '01101000', '01100001', '01100100', '00100000', '01101000', '01100101', '01100001', '01110010', '01100100', '00100000', '01110100', '01101000', '01100101', '00100000', '01110011', '01110100', '01101111', '01110010', '01101001', '01100101', '01110011', '00100000', '01100110', '01110010', '01101111', '01101101', '00100000', '01101000', '01100101', '01110010', '00100000', '01100111', '01110010', '01100001', '01101110', '01100100', '01101101', '01101111', '01110100', '01101000', '01100101', '01110010', '00101100', '00100000', '01100001', '01101110', '01100100', '00100000', '01110011', '01101000', '01100101', '00100000', '01110111', '01100001', '01110011', '00100000', '01100100', '01 ...
# The Lost City
#
# Deep in the heart of the Amazon rainforest, there lies a lost city.
# It is said to be filled with gold and treasures beyond compare.
# Many have searched for it, but none have ever returned.
#
# One day, a young woman named Anya set out to find the lost city.
# She had heard the stories from her grandmother, and she was determined to prove that they were true.
#
# Anya traveled for many days and nights.
# She crossed rivers, climbed mountains, and fought through dense jungle.
# Finally, she came to a clearing. In the center of the clearing was a magnificent city.
#
# The city was made of gold and precious stones.
# It was more beautiful than anything Anya had ever seen before.
# She walked into the city and began to explore.
#
# Anya found many treasures in the city.
# She found gold statues, diamond necklaces, and emerald crowns.
# But the most valuable treasure she found was the knowledge of the ancient people who had built the city.
#
# Anya stayed in the lost city for many days.
# She learned everything she could about the ancient people and their culture.
# Then, she returned to her village and shared her knowledge with others.
#
# Anya's discovery of the lost city changed the world.
# It showed that there were still many mysteries to be discovered in the Amazon rainforest.
# And it inspired others to go out and explore the world.
